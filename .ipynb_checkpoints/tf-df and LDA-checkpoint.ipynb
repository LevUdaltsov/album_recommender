# %% [markdown]
# # This is a notebook to demonstrate how the tf-idf combined with an Autoencoder approach can be used to convert album reviews into 3 dimensional points in space.

# %%
import numpy as np
from src.utils import load_data, get_artist_albums, plot_encoded_albums
documents = load_data('pitchfork_reviews.csv')
encoded_albums = np.load('encoded_reviews.npy')
# %matplotlib notebook

# %%
artists = ['kanye west', 'kendrick lamar', 'coldplay', 'ariana grande']

# %%
album_df = get_artist_albums(documents, artists)

# %%
plot_encoded_albums(encoded_albums, album_df)
# Out:
# /home/lev/projects/album_recommender/src/utils.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['artist'] = album_df['artist'].astype('category')
# <img src="data:image/png;base64,..." width="700">

# %%
album_df['artist'].cat.codes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5d1719fdf618> in <module>
# ----> 1 album_df['artist'].cat.codes
#
# ~/dsenv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5454             or name in self._accessors
#    5455         ):
# -> 5456             return object.__getattribute__(self, name)
#    5457         else:
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/dsenv/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# ~/dsenv/lib/python3.8/site-packages/pandas/core/arrays/categorical.py in __init__(self, data)
#    2455
#    2456     def __init__(self, data):
# -> 2457         self._validate(data)
#    2458         self._parent = data.values
#    2459         self._index = data.index
#
# ~/dsenv/lib/python3.8/site-packages/pandas/core/arrays/categorical.py in _validate(data)
#    2464     def _validate(data):
#    2465         if not is_categorical_dtype(data.dtype):
# -> 2466             raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#    2467
#    2468     def _delegate_property_get(self, name):
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
sample_doc_encoded = np.asarray([X[item] for item in sample_docs.index])
album_list = list(sample_docs['artist'].values)
fig = plt.figure(1, figsize=(7, 7))
ax = Axes3D(fig, rect=[0, 0, 1, 1], elev=48, azim=134)

ax.scatter(sample_doc_encoded[:, 0], sample_doc_encoded[:, 1], sample_doc_encoded[:, 2],
           c=np.array(sample_docs['artist'].cat.codes).astype(np.float))

for i, txt in enumerate(album_list):
    ax.text(sample_doc_encoded[i, 0], sample_doc_encoded[i, 1], sample_doc_encoded[i, 2], txt, fontsize=8)
ax.dist = 12
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
check_albums = documents[(documents['artist']=='kendrick lamar' )| (documents['artist']=='radiohead') | (documents['artist']=='the gaslight anthem') | (documents['artist']=='run the jewels')]
documents[documents['artist'] == 'the beatles']
# Out:
#             artist                                  title  \
# 3671   the beatles        on air - live at the bbc vol. 2
# 8615   the beatles                            the beatles
# 8616   the beatles                       yellow submarine
# 8617   the beatles                             abbey road
# 8618   the beatles                              let it be
# 8619   the beatles                           past masters
# 8620   the beatles                            rubber soul
# 8621   the beatles                               revolver
# 8622   the beatles  sgt. pepper's lonely hearts club band
# 8623   the beatles                   magical mystery tour
# 8624   the beatles                              rock band
# 8625   the beatles                       please please me
# 8626   the beatles                       with the beatles
# 8627   the beatles                     a hard day's night
# 8628   the beatles                       beatles for sale
# 8629   the beatles                                  help!
# 8630   the beatles                             stereo box
# 11934  the beatles                                   love
# 12680  the beatles             the capitol albums, vol. 2
# 14340  the beatles             the capitol albums, vol. 1
# 15425  the beatles                     let it be... naked
#
#                                                  content  score
# 3671   The Beatles mythos is a sum of historic locati...    7.2
# 8615   In his review of the Beatles' 1963 LP debut, P...   10.0
# 8616   Hey, nobody's perfect. The only truly minor al...    6.2
# 8617   One more "like we used to" was how Paul McCart...   10.0
# 8618   As the 1960s wound down, so did the Beatles. T...    9.1
# 8619   Past Masters is the  ugly but brilliant siblin...    9.2
# 8620   To modern ears, Rubber Soul and its pre-psyche...   10.0
# 8621   Like any band, the Beatles' recording career w...   10.0
# 8622   Finally free of touring, the Beatles next soug...   10.0
# 8623   After the death of manager Brian Epstein, the ...   10.0
# 8624   Here's the story of the Beatles, as told by th...    9.5
# 8625   Whether or not you think the Beatles  are the ...    9.5
# 8626   Would that today's PRs had the honesty  of Bea...    8.8
# 8627   Pop in 1964 was part of showbiz: Once  the Bea...    9.7
# 8628   The Beatles faced the same pressures  every te...    9.3
# 8629   In A Hard Days Night, after throwing a sarky G...    9.2
# 8630   In 1987, the Beatles' albums appeared on compa...   10.0
# 11934  John Lennon's "Glass Onion", a daffy throwaway...    8.5
# 12680  I admit it. I was a little harsh on these guys...    7.5
# 14340  \n    \n    I. What is this box set about?\n\n...    6.0
# 15425  "I Dig a Pygmy by Charles Hawtrey & The Deaf A...    7.0

# %%
check_albums
# Out:
#                     artist                                          title  \
# 11          run the jewels                               run the jewels 3
# 818              radiohead                             a moon shaped pool
# 1046        kendrick lamar                           untitled unmastered.
# 1511        run the jewels                                meow the jewels
# 2171        kendrick lamar                            to pimp a butterfly
# 2557        run the jewels                               run the jewels 2
# 2803   the gaslight anthem                                       get hurt
# 4135        run the jewels                                 run the jewels
# 4955        kendrick lamar                         good kid, m.a.a.d city
# 5252   the gaslight anthem                                    handwritten
# 6170             radiohead                               tkol rmx 1234567
# 6420        kendrick lamar                                     section.80
# 6930             radiohead                              the king of limbs
# 7711   the gaslight anthem                                 american slang
# 8661             radiohead  hail to the thief: special collectors edition
# 8666             radiohead           amnesiac: special collectors edition
# 8671             radiohead              kid a: special collectors edition
# 9101             radiohead               pablo honey: collector's edition
# 9523   the gaslight anthem                                  the '59 sound
# 10112            radiohead                                    the best of
# 10667            radiohead                             in rainbows [cd 2]
# 10877            radiohead                                    in rainbows
# 17376            radiohead           i might be wrong: live recordings ep
# 17697            radiohead                                       amnesiac
# 17898            radiohead                                          kid a
#
#                                                  content  len_review
# 11     On 2006’s “That’s Life,” Killer Mike boasted “...         823
# 818    Radiohead, who titled their ninth studio album...        1124
# 1046   "I made To Pimp a Butterfly for you," raps Ken...         855
# 1511   Cats are the Internet's favorite pets for many...         868
# 2171   Kendrick Lamar’s major-label albums play out l...         847
# 2557   Trigger warning: If you or someone you love is...        1894
# 2803   Who says the Gaslight Anthem doesn’t have a se...         997
# 4135   Even for those of us who go all the way back t...        1091
# 4955   The first sound we hear on good kid, m.A.A.d. ...         932
# 5252   Brian Fallon doesn't seem like the kind of guy...         671
# 6170   Radiohead has a reputation for studio perfecti...         616
# 6420   Kendrick Lamar is a weird kid, and rap music c...         667
# 6930   Now that the music on In Rainbows has  had fou...         850
# 7711   Where so many young rock bands struggle to lib...         564
# 8661   By 2003, Radiohead were trapped in a musical e...        1127
# 8666   You've released a series of masterpieces in a ...        1303
# 8671   We used to listen to music in an entirely diff...        1001
# 9101   When Capitol released a few different shortcut...        1693
# 9523   Here's Gaslight Anthem frontman Brian Fallon o...         589
# 10112  The week after Radiohead's OK Computer was rel...        1309
# 10667  \n    The "pay what you want" fire sale that l...         672
# 10877  Like many music lovers of a certain age, I hav...        1221
# 17376  The bright lights flashed in unison like cheap...         993
# 17697  After months of waiting, and several tentative...         974
# 17898  I had never even seen a shooting star before. ...        1238

# %%
albums_i_like = ['run the jewels 2', 'to pimp a butterfly', 'in rainbows', 'american slang']
albums_i_like_idx= list(documents[documents.title.isin(albums_i_like)].index)
list_of_points = []

for index in albums_i_like_idx:
    list_of_points.append(X[index])

list_of_points
# Out:
# [array([-0.45591772, -0.01160568,  0.02992859], dtype=float32),
#  array([-0.9018583 ,  0.01481776,  0.07123911], dtype=float32),
#  array([-0.07373562, -0.6009283 , -1.0763252 ], dtype=float32),
#  array([-0.10259155, -0.9931934 , -1.1196787 ], dtype=float32)]

# %%
mean_point = np.mean(list_of_points, axis=0)

from scipy.stats import gmean
g_mean_point = gmean(list_of_points, axis=0)
list_of_points.append(g_mean_point)
X_test = np.asarray(list_of_points)
# Out:
# [array([-0.1511252 , -0.1366487 , -0.37766623], dtype=float32),
#  array([-1.2165605, -1.4816178, -0.8945276], dtype=float32),
#  array([-0.31573698, -0.11191535, -0.37040484], dtype=float32),
#  array([-0.19224234, -0.5060732 , -1.2371645 ], dtype=float32),
#  array([-0.46891627, -0.55906373, -0.7199408 ], dtype=float32),
#  array([-0.46891627, -0.55906373, -0.7199408 ], dtype=float32),
#  array([-0.46891627, -0.55906373, -0.7199407 ], dtype=float32),
#  array([nan, nan, nan], dtype=float32),
#  array([nan, nan, nan], dtype=float32),
#  array([nan, nan, nan], dtype=float32),
#  array([nan, nan, nan], dtype=float32),
#  array([nan, nan, nan], dtype=float32)]

# %%
documents[documents.title.isin(albums_i_like)]
# Out:
#                     artist                title  \
# 2171        kendrick lamar  to pimp a butterfly
# 2557        run the jewels     run the jewels 2
# 7711   the gaslight anthem       american slang
# 10877            radiohead          in rainbows
#
#                                                  content  len_review
# 2171   Kendrick Lamar’s major-label albums play out l...         847
# 2557   Trigger warning: If you or someone you love is...        1894
# 7711   Where so many young rock bands struggle to lib...         564
# 10877  Like many music lovers of a certain age, I hav...        1221

# %%
closest_node(mean_point, good_reviews_data)
# Out:
# 0

# %%
documents.iloc[2390]
# Out:
# artist                                          rae sremmurd
# title                                              sremmlife
# content    Last year, buoyed by effervescent hits like th...
# score                                                    7.8
# Name: 2390, dtype: object

# %%
album_list = albums_i_like + ['sremmlife']
sample_doc_encoded = np.asarray([X[item] for item in sample_docs.index])
fig = plt.figure(1, figsize=(7, 7))
ax = Axes3D(fig, rect=[0, 0, 1, 1], elev=48, azim=134)

ax.scatter(X_test[:, 0], X_test[:, 1], X_test[:, 2])

for i, txt in enumerate(album_list):
    ax.text(X_test[i, 0], X_test[i, 1], X_test[i, 2], txt, fontsize=8)
    
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.dist = 12

# %%
albums_list
# Out:
# ['run the jewels 2',
#  'to pimp a butterfly',
#  'in rainbows',
#  'american slang',
#  'puerto muerto']

# %%
good_reviews_data = [X[i] for i in good_reviews.index]

# %%
albums_i_like = ['is this it', 'pure heroine', 'mingus ah um: legacy edition', 'untrue']
albums_i_like_idx= list(documents[documents.title.isin(albums_i_like)].index)
list_of_points = []

for index in albums_i_like_idx:
    list_of_points.append(X[index])

list_of_points
mean_point = np.mean(list_of_points, axis=0)

from scipy.stats import gmean
g_mean_point = gmean(list_of_points, axis=0)
list_of_points.append(g_mean_point)
X_test = np.asarray(list_of_points)

# %%
g_mean_point
# Out:
# array([nan, nan, nan], dtype=float32)

# %%
gmean([X_test[0]])
# Out:
# array([nan, nan, nan], dtype=float32)

# %%
X_test[0]
# Out:
# array([-0.1511252 , -0.1366487 , -0.37766623], dtype=float32)
