# %% [markdown]
# # This is a notebook to demonstrate how the tf-idf combined with an Autoencoder approach can be used to convert album reviews into 3 dimensional points in space.

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.utils import load_data, get_artist_albums, plot_encoded_albums, get_recommendation, create_df, tfidf_generator
documents = load_data('pitchfork_reviews.csv')
encoded_albums = np.load('encoded_reviews.npy')
plt.style.use('seaborn')
# %matplotlib notebook

# %%
artists_1 = ['kanye west', 'kendrick lamar', 'coldplay', 'ariana grande']

# %%
plt.cla()
album_df_1 = get_artist_albums(documents, artists_1)
plot_encoded_albums(encoded_albums, album_df_1, labels=False)

# %%
data_tfidf, tfidf_tokens = tfidf_generator(documents, 10)
create_df(documents, data_tfidf, tfidf_tokens)

# %%
plt.cla()

artists_2 = ['mf doom', 'radiohead', 'disclosure', 'run the jewels']
album_df_2 = get_artist_albums(documents, artists_2)
plot_encoded_albums(encoded_albums, album_df_2, labels=False)

# %%
albums = ['my beautiful dark twisted fantasy', 'daytona', 'in rainbows', 'run the jewels 2']

# %%
albums = ['my beautiful dark twisted fantasy', 'songs for the deaf', 'in rainbows', 'run the jewels 2']
get_recommendation(documents, encoded_albums, albums)
# Out:
# 2979
# artist                                      various artists
# album                    eccentric soul: the big mack label
# review    \n    It's one of thousands of vacant lots tha...
# score                                                   8.1
# Name: 12492, dtype: object
# <img src="data:image/png;base64,..." width="640">
# /home/lev/projects/album_recommender/src/utils.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['artist'] = album_df['artist'].astype('category')
# ...

# %%
test

# %%
album_df_2

# %%
test = get_recommendation(documents, encoded_albums, albums)
test[1]

# %%
documents['len'] = [len(item.split()) for item in documents['review'].values]

# %%
fig = plt.figure(figsize=(10,10))
ax = documents['len'].hist(bins=100)
ax.set_title('Distribution of document legnth in album review dataset')
ax.set_xlabel("Document Length")
ax.set_ylabel("Number of Documents")
plt.axvline(x=np.mean(documents['len']),c='red')
plt.savefig('/home/lev/projects/LevUdaltsov.github.io/assets/images/albumhist.jpg', dpi=300)

# %%
np.mean(documents['len'])

# %%
documents
