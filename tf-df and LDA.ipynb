# %% [markdown]
# # This is a notebook to demonstrate how the tf-idf combined with an Autoencoder approach can be used to convert album reviews into 3 dimensional points in space.

# %%
import numpy as np
from src.utils import load_data, get_artist_albums, plot_encoded_albums, get_recommendation
documents = load_data('pitchfork_reviews.csv')
encoded_albums = np.load('encoded_reviews.npy')
# %matplotlib notebook

# %%
artists_1 = ['kanye west', 'kendrick lamar', 'coldplay', 'ariana grande']

# %%
album_df_1 = get_artist_albums(documents, artists_1)
plot_encoded_albums(encoded_albums, album_df_1, labels=True)
# Out:
# /home/lev/projects/album_recommender/src/utils.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['artist'] = album_df['artist'].astype('category')
# <img src="data:image/png;base64,..." width="700">

# %%
artists_2 = ['mf doom', 'radiohead', 'disclosure', 'run the jewels']
album_df_2 = get_artist_albums(documents, artists_2)
plot_encoded_albums(encoded_albums, album_df_2, labels=True)

# %%
albums = ['my beautiful dark twisted fantasy', 'daytona', 'in rainbows', 'run the jewels 2']

# %%
get_recommendation(documents, encoded_albums, albums)
# Out:
# 2979
# artist                                          death grips
# album                                     government plates
# review    Whenever Death Grips get accused of bad intent...
# score                                                   8.4
# Name: 3656, dtype: object

# %%
album_df_2.loc[11]
# Out:
# artist                                       run the jewels
# album                                      run the jewels 3
# review    On 2006’s “That’s Life,” Killer Mike boasted “...
# score                                                   8.6
# Name: 11, dtype: object

# %%
album_df_2
# Out:
#                artist                                          album  \
# 11     run the jewels                               run the jewels 3
# 663        disclosure                                  moog for love
# 818         radiohead                             a moon shaped pool
# 1511   run the jewels                                meow the jewels
# 1536       disclosure                                        caracal
# 2557   run the jewels                               run the jewels 2
# 3541       disclosure                            settle: the remixes
# 4135   run the jewels                                 run the jewels
# 4230       disclosure                                         settle
# 6170        radiohead                               tkol rmx 1234567
# 6721          mf doom                            operation: doomsday
# 6930        radiohead                              the king of limbs
# 7416          mf doom                             expektoration live
# 8661        radiohead  hail to the thief: special collectors edition
# 8666        radiohead           amnesiac: special collectors edition
# 8671        radiohead              kid a: special collectors edition
# 9101        radiohead               pablo honey: collector's edition
# 10112       radiohead                                    the best of
# 10667       radiohead                             in rainbows [cd 2]
# 10877       radiohead                                    in rainbows
# 14364         mf doom                                      mm..food?
# 17376       radiohead           i might be wrong: live recordings ep
# 17697       radiohead                                       amnesiac
# 17898       radiohead                                          kid a
#
#                                                   review  score
# 11     On 2006’s “That’s Life,” Killer Mike boasted “...    8.6
# 663    Coachella can be a little bit like high school...    6.0
# 818    Radiohead, who titled their ninth studio album...    9.1
# 1511   Cats are the Internet's favorite pets for many...    7.0
# 1536   Looking back, the intro to Disclosure’s Settle...    6.6
# 2557   Trigger warning: If you or someone you love is...    9.0
# 3541   One of Disclosure's signatures is their abilit...    5.9
# 4135   Even for those of us who go all the way back t...    8.5
# 4230   In recent years, dance music's growing mainstr...    9.1
# 6170   Radiohead has a reputation for studio perfecti...    6.0
# 6721   Whether a classic archetype like Superman or a...    8.9
# 6930   Now that the music on In Rainbows has  had fou...    7.9
# 7416   Part of the appeal of a live album is that it'...    6.0
# 8661   By 2003, Radiohead were trapped in a musical e...    8.6
# 8666   You've released a series of masterpieces in a ...    9.5
# 8671   We used to listen to music in an entirely diff...   10.0
# 9101   When Capitol released a few different shortcut...    5.4
# 10112  The week after Radiohead's OK Computer was rel...    4.0
# 10667  \n    The "pay what you want" fire sale that l...    6.2
# 10877  Like many music lovers of a certain age, I hav...    9.3
# 14364  Rap loves food. Skeptics: name another genre t...    7.5
# 17376  The bright lights flashed in unison like cheap...    8.0
# 17697  After months of waiting, and several tentative...    9.0
# 17898  I had never even seen a shooting star before. ...   10.0

# %%
get_recommendation(documents, encoded_albums, albums)
# Out:
# 2979
# artist                                          death grips
# album                                     government plates
# review    Whenever Death Grips get accused of bad intent...
# score                                                   8.4
# Name: 3656, dtype: object
