# %%
import sys
from urllib.request import urlopen
import time
import datetime
import MySQLdb
import xml.etree.ElementTree as ET
from datetime import datetime
from bs4 import BeautifulSoup

# %%
url = "http://pitchfork.com/rss/reviews/albums/"
response = urlopen(url)
xmlfeed = response.read()

# %%
with open('albums.xml', 'wb') as f:
    f.write(xmlfeed)
    f.close()

# %%
root = ET.parse('albums.xml').getroot()
for child in root.iter('item'):
    title = child.find('title').text.encode('utf-8')
    description = child.find('description').text.encode('utf-8')
    link = child.find('link').text
    guid = child.find('guid').text
    pubDate = child.find('pubDate').text
    str_to_parse = pubDate.replace(" +0000","")
    review_date = datetime.strptime(str_to_parse, '%a, %d %b %Y %H:%M:%S')

# %%
title = child.find('title').text
description = child.find('description').text
link = child.find('link').text
guid = child.find('guid').text
pubDate = child.find('pubDate').text
str_to_parse = pubDate.replace(" +0000","")
review_date = datetime.strptime(str_to_parse, '%a, %d %b %Y %H:%M:%S')
artist = title.split(': ')[0]
medic = title.split(': ')[1]

# %%
html_review = urlopen(link).read()

# %%
html_soup = BeautifulSoup(html_review, 'html.parser')

# %%
html_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
html_soup.title
# Out:
# <title data-react-helmet="true">Field Medic: Floral Prince Album Review | Pitchfork</title>

# %%
html_soup.find("h2").get_text()
# Out:
# 'Field Medic'

# %%
score = html_soup.select("span.score")

# %%
score
# Out:
# [<span class="score">6.9</span>]

# %%
import json
json_file = '../media/reviews.json'

# %%
with open(json_file, 'r') as review_file:
    reviews = json.load(review_file)

# %%
reviews[0]
# Out:
# {'artist': 'massive attack',
#  'author': 'nate patrin',
#  'author_type': 'contributor',
#  'best_new_music': 0,
#  'pub_date': '2017-01-08',
#  'pub_day': 8,
#  'pub_month': 1,
#  'pub_weekday': 6,
#  'pub_year': 2017,
#  'reviewid': 22703,
#  'score': 9.3,
#  'title': 'mezzanine',
#  'url': 'http://pitchfork.com/reviews/albums/22703-mezzanine/'}

# %%
reviews_json = '../media/reviews.json'
content_json = '../media/content.json'

with open(reviews_json, 'r') as f:
    reviews = json.load(f)

with open(content_json, 'r') as f:
    content = json.load(f)

# %%
reviews
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-470bec042f77> in <module>
# ----> 1 reviews
#
# NameError: name 'reviews' is not defined

# %%
reviews[0]
# Out:
# {'artist': 'massive attack',
#  'author': 'nate patrin',
#  'author_type': 'contributor',
#  'best_new_music': 0,
#  'pub_date': '2017-01-08',
#  'pub_day': 8,
#  'pub_month': 1,
#  'pub_weekday': 6,
#  'pub_year': 2017,
#  'reviewid': 22703,
#  'score': 9.3,
#  'title': 'mezzanine',
#  'url': 'http://pitchfork.com/reviews/albums/22703-mezzanine/'}

# %%
from datetime import datetime
datetime.strptime(reviews[0]['pub_date'], '%Y-%m-%d')
# Out:
# datetime.datetime(2017, 1, 8, 0, 0)

# %%
reviews[0]['pub_date']
# Out:
# str

# %%
import pandas as pd

# %%
reviews_json = '../media/pitchfork_reviews.csv'

# %%
df = pd.read_csv(reviews_json)

# %%
import tqdm

# %%
for _, row in df.iterrows():
    print(row['title'])
# Out:
# mezzanine
# prelapsarian
# all of them naturals
# first songs
# new start
# insecure (music from the hbo original series)
# stillness in wonderland
# tehillim
# reflection
# filthy america its beautiful
# clear sounds/perfetta
# run the jewels 3
# nadir
# december 99th
# don't smoke rock
# punk45: les punks: the french connection (the first wave of french punk 1977-80)
# brnshj (puncak)
# merry christmas lil mama
# ///// effectual
# love you to death
# what graceless dawn
# not the actual events ep
# holy science
# early tapes, 1996-1998
# the wasp factory
# a very kacey christmas
# turn into
# traditional music of notional species vol. ii
# swiss radio days vol. 41 - zurich 1961
# do what thou wilt.
# the great southern trendkill
# the return of east atlanta santa
# jackie ost
# passion, pain & demon slayin
# pieces in space
# fireplace: thenottheotherside
# slight freedom
# in the loop: a decade of remixes
# heart song
# american boyfriend: a suburban love story
# throat
# ...

# %%
df.head()
# Out:
#    reviewid                  name            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type   pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor 2017-01-08            6        8
# ...

# %%
from datetime import datetime 
df.rename(columns={'title': 'name'}, inplace=True)
df[['name', 'pub_date', 'artist', 'content', 'url', 'score', 'best_new_music']]
df['pub_date'] = [datetime.strptime(item, '%Y-%m-%d') for item in df['pub_date'].values]
